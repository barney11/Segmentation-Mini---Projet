# %% [markdown]
# # Segmentation d'images - Mini Projet

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
# 1 - Importer les images

# %%
I = cv.imread('eight.tif')
np.shape(I)
# Out:
# (242, 308, 3)

# %%
plt.imshow(I)

# %%
# 2 - Utiliser fonction roipoly pour créer un masque binaire

# %%
# 3 - INIT PHI : fonctions signed_distance_from_mask et fast_marching

# %% [markdown]
# ## Alternate Minimization

# %%
# 4 - fonction Heaviside-Eta

# %%
# 5 - delta-eta, gradx, grady, div
